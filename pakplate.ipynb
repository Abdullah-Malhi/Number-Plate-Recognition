# %%
pip install kaggle

# %%
mkdir ~/.kaggle

# %%
cp kaggle.json ~/.kaggle/

# %%
# !kaggle datasets download -d bcs153058sabeeh/pakistani-number-plate-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/bcs153058sabeeh/pakistani-number-plate-dataset
# License(s): Apache 2.0
# ...
# 100% 653M/654M [00:41<00:00, 18.2MB/s]
# 100% 654M/654M [00:41<00:00, 16.6MB/s]

# %%
# !unzip pakistani-number-plate-dataset.zip
# Out:
# Archive:  pakistani-number-plate-dataset.zip
#   inflating: NumberPlateDataset1000/images/train/1.jpg
#   inflating: NumberPlateDataset1000/images/train/10.jpg
#   inflating: NumberPlateDataset1000/images/train/100.jpg
#   inflating: NumberPlateDataset1000/images/train/101.jpg
#   inflating: NumberPlateDataset1000/images/train/102.jpg
#   inflating: NumberPlateDataset1000/images/train/103.jpg
#   inflating: NumberPlateDataset1000/images/train/104.jpg
#   inflating: NumberPlateDataset1000/images/train/105.jpg
#   inflating: NumberPlateDataset1000/images/train/106.jpg
#   inflating: NumberPlateDataset1000/images/train/107.jpg
#   inflating: NumberPlateDataset1000/images/train/108.jpg
#   inflating: NumberPlateDataset1000/images/train/109.jpg
#   inflating: NumberPlateDataset1000/images/train/11.jpg
#   inflating: NumberPlateDataset1000/images/train/110.jpg
#   inflating: NumberPlateDataset1000/images/train/111.jpg
#   inflating: NumberPlateDataset1000/images/train/112.jpg
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 799.4/799.4 kB 14.0 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
ROOT_DIR='/content/pakistani-number-plate-dataset'

# %%
import os
from ultralytics import YOLO
model = YOLO("yolov8n.yaml")
results = model.train(data=os.path.join(ROOT_DIR,"/content/config.yaml"),epochs=10)
# Out:
# Ultralytics YOLOv8.2.50 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Run the scp command with the correct locale setting
# !LC_ALL=C.UTF-8 LANG=C.UTF-8 scp -r /content/runs '/content/NumberPlateDataset1000'
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-13-cf36f3c20270> in <cell line: 2>()
#       1 # Run the scp command with the correct locale setting
# ----> 2 get_ipython().system("LC_ALL=C.UTF-8 LANG=C.UTF-8 scp -r /content/runs '/content/NumberPlateDataset1000'")
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      97       kwargs.update({'also_return_output': True})
#      98
# ---> 99     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     100
#     101     if pip_warn:
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     452   # is expected to call this function, thus adding one level of nesting to the
#     453   # stack.
# --> 454   result = _run_command(
# ...
